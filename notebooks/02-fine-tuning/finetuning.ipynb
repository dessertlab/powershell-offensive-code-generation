# %% [markdown]
# # Training
# The fine tuning of pre-trained model has been conducted relyng on Microsoft's [CodeXGlue](https://github.com/microsoft/CodeXGLUE) framework, therefore the fine-tuning only needs to run:

# %%
# !../../text-to-code/run_exp_finetuning.sh ../json [INSERT PRE-TRAINED MODEL PATH] [NUMBER OF EPOQUES] stub [INSERT HF TOKEN]
